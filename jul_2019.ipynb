# %%
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,4 # define as dimensões do gráficos a seguir

# %%
# Dados de METAR de Guarulhos nos ano de 2019
df = pd.read_csv('metar_sbgr_julho_2019.csv')

# %%
df=df.drop(['station'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valid   763 non-null    object
#  1   tmpc    763 non-null    float64
#  2   dwpc    763 non-null    float64
#  3   relh    763 non-null    float64
#  4   drct    763 non-null    float64
#  5   sknt    763 non-null    float64
#  6   vsby    763 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 41.9+ KB

# %%
df['datetime'] = pd.to_datetime(df['valid'])
df = df.set_index('datetime')
df.drop(['valid'], axis=1, inplace=True)
df.head()
# Out:
#                      tmpc  dwpc   relh  drct  sknt  vsby
# datetime
# 2019-07-01 00:00:00  17.0  15.0  88.00   0.0   0.0  6.21
# 2019-07-01 01:00:00  18.0  15.0  82.62  70.0   3.0  6.21
# 2019-07-01 02:00:00  17.0  15.0  88.00  70.0   5.0  6.21
# 2019-07-01 03:00:00  17.0  15.0  88.00  80.0   3.0  6.21
# 2019-07-01 04:00:00  16.0  14.0  87.92  80.0   5.0  6.21

# %%
# Visibilidade no decorrer do mes de JUL2019
df['2019-07-01':'2019-07-31'].vsby.plot()

# %%
import datetime
h=pd.Timestamp(datetime.datetime(2019, 7, 1,3))

# %%
h
# Out:
# Timestamp('2019-07-01 03:00:00')

# %%
#Escolhe o dia e plota a visibilidade
df[df.index.day == 30].vsby.plot()

# %%
#df['2019-07-07':'2019-07-09'].vsby.plot()
df['2019-07-29':'2019-07-31'].vsby.plot()
#df['2019-07-09':'2019-07-11'].vsby.plot()

# %%
df['2019-07-07'].vsby.plot()

# %%
df['2019-07-09':'2019-07-11'].vsby.plot()

# %%
df['2019-07-09':'2019-07-11'].tmpc.plot()
df['2019-07-09':'2019-07-11'].dwpc.plot()

# %%
df['2019-07-09':'2019-07-11'].relh.plot()

# %%
df['2019-07-07':'2019-07-09'].sknt.plot()

# %%
df['2019-07-07':'2019-07-09'].drct.plot()

# %%
df['2019-07-07':'2019-07-09'].drct.plot()
df['2019-07-07':'2019-07-09'].sknt.plot(secondary_y=True, style='g')

# %%
df['2019-07-07':'2019-07-09'].vsby.plot()
df['2019-07-07':'2019-07-09'].sknt.plot(secondary_y=True, style='g')

# %%
df['2019-07-07':'2019-07-09'].vsby.plot()
df['2019-07-07':'2019-07-09'].tmpc.plot(secondary_y=True, style='g')

# %%
df['2019-07-07':'2019-07-09'].vsby.plot()
df['2019-07-07':'2019-07-09'].relh.plot(secondary_y=True, style='g')

# %%
dia=30
df[df.index.day == dia].vsby.plot()
#df[df.index.day == dia].dwpc.plot(secondary_y=True, style='g')
#df[df.index.day == dia].twpc.plot(secondary_y=True, style='g')
#df[df.index.day == dia].drct.plot(secondary_y=True, style='g')
df[df.index.day == dia].sknt.plot(secondary_y=True, style='g')
