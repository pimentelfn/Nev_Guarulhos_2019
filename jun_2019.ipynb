# %%
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,4 # define as dimensões do gráficos a seguir

# %%
# Dados de METAR de Guarulhos nos ano de 2019
df = pd.read_csv('metar_sbgr_junho_2019.csv')

# %%
df=df.drop(['station'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valid   736 non-null    object
#  1   tmpc    736 non-null    float64
#  2   dwpc    736 non-null    float64
#  3   relh    736 non-null    float64
#  4   drct    736 non-null    float64
#  5   sknt    736 non-null    float64
#  6   vsby    736 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 40.4+ KB

# %%
df['datetime'] = pd.to_datetime(df['valid'])
df = df.set_index('datetime')
df.drop(['valid'], axis=1, inplace=True)
df.head()
# Out:
#                      tmpc  dwpc    relh   drct  sknt  vsby
# datetime
# 2019-06-01 00:00:00  24.0  16.0   60.90  290.0   5.0  6.21
# 2019-06-01 01:00:00  22.0  17.0   73.27  230.0   3.0  6.21
# 2019-06-01 01:05:00  22.0  18.0   78.04  230.0  10.0  6.21
# 2019-06-01 02:00:00  19.0  19.0  100.00  230.0   2.0  4.35
# 2019-06-01 02:28:00  19.0  19.0  100.00    0.0   0.0  6.21

# %%
df['2019-06-01':'2019-06-30'].vsby.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
#Escolhe o dia e plota a visibilidade
df[df.index.day == 7].vsby.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-03':'2019-06-09'].vsby.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-03':'2019-06-09'].tmpc.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-03':'2019-06-09'].sknt.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-03':'2019-06-09'].drct.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-06':'2019-06-08'].tmpc.plot(figsize=(15,6), linewidth=3, fontsize=10)
df['2019-06-06':'2019-06-08'].dwpc.plot(figsize=(15,6), linewidth=3, fontsize=10)

# %%
df['2019-06-05':'2019-06-08'].tmpc.plot()
df['2019-06-05':'2019-06-08'].vsby.plot(secondary_y=True, style='g')

# %%
df['2019-06-05':'2019-06-08'].sknt.plot()
df['2019-06-05':'2019-06-08'].vsby.plot(secondary_y=True, style='g')
