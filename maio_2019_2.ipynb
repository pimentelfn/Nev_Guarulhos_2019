# %%
from pandas import read_csv
sr = read_csv( 'metar_sbgr_maio_2019.csv' , header=0, index_col=1, parse_dates=True,
squeeze=True)

# %%
sr
# Out:
#                     station  tmpc  dwpc    relh   drct  sknt  vsby
# valid
# 2019-05-01 00:00:00    SBGR  20.0  18.0   88.26  130.0   2.0  5.59
# 2019-05-01 01:00:00    SBGR  20.0  18.0   88.26  150.0   3.0  6.21
# 2019-05-01 02:00:00    SBGR  20.0  18.0   88.26  130.0   3.0  6.21
# 2019-05-01 03:00:00    SBGR  18.0  18.0  100.00    0.0   0.0  3.73
# 2019-05-01 04:00:00    SBGR  18.0  18.0  100.00   90.0   2.0  3.73
# ...                     ...   ...   ...     ...    ...   ...   ...
# 2019-05-30 19:00:00    SBGR  21.0  19.0   88.34  150.0   8.0  3.11
# 2019-05-30 20:00:00    SBGR  21.0  18.0   82.98  130.0   3.0  5.59
# 2019-05-30 21:00:00    SBGR  21.0  18.0   82.98   80.0   4.0  6.21
# 2019-05-30 22:00:00    SBGR  21.0  18.0   82.98  110.0   2.0  6.21
# 2019-05-30 23:00:00    SBGR  20.0  18.0   88.26   10.0   2.0  6.21
#
# [773 rows x 7 columns]

# %%
sr.vsby.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
sr.vsby.plot(figsize=(20,10), linewidth=5, fontsize=20)
sr.tmpc.plot(figsize=(20,10), linewidth=5, fontsize=20)
sr.dwpc.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
sr.vsby.plot(figsize=(20,10), linewidth=5, fontsize=20)
sr.relh.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
sr.sknt.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
sr.drct.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
df = pd.read_csv('metar_sbgr_maio_2019.csv',index_col=1,squeeze=True,parse_dates=True,)
df=df.drop(['station'], axis=1)
df.head()
# Out:
#                      tmpc  dwpc    relh   drct  sknt  vsby
# valid
# 2019-05-01 00:00:00  20.0  18.0   88.26  130.0   2.0  5.59
# 2019-05-01 01:00:00  20.0  18.0   88.26  150.0   3.0  6.21
# 2019-05-01 02:00:00  20.0  18.0   88.26  130.0   3.0  6.21
# 2019-05-01 03:00:00  18.0  18.0  100.00    0.0   0.0  3.73
# 2019-05-01 04:00:00  18.0  18.0  100.00   90.0   2.0  3.73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 773 entries, 2019-05-01 00:00:00 to 2019-05-30 23:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tmpc    773 non-null    float64
#  1   dwpc    773 non-null    float64
#  2   relh    773 non-null    float64
#  3   drct    773 non-null    float64
#  4   sknt    773 non-null    float64
#  5   vsby    773 non-null    float64
# dtypes: float64(6)
# memory usage: 42.3 KB

# %%
df.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
df[['tmpc']].plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Data', fontsize=20);

# %%
tmpc = df[['tmpc']]
tmpc.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
relh = df[['relh']]
relh.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
vsby = df[['vsby']]
vsby.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
dwpc = df[['dwpc']]
dwpc.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
df_rm = pd.concat([tmpc.rolling(12).mean(), dwpc.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
vsby.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
tmpc.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
df.tmpc.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
df.dwpc.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
df.corr()
# Out:
#           tmpc      dwpc      relh      drct      sknt      vsby
# tmpc  1.000000  0.472379 -0.757739  0.472200  0.265727  0.271225
# dwpc  0.472379  1.000000  0.208467 -0.156959 -0.094000 -0.084844
# relh -0.757739  0.208467  1.000000 -0.637775 -0.377743 -0.390393
# drct  0.472200 -0.156959 -0.637775  1.000000  0.453331  0.286216
# sknt  0.265727 -0.094000 -0.377743  0.453331  1.000000  0.095748
# vsby  0.271225 -0.084844 -0.390393  0.286216  0.095748  1.000000

# %%
df.diff().corr()
# Out:
#           tmpc      dwpc      relh      drct      sknt      vsby
# tmpc  1.000000  0.036127 -0.849413  0.287002  0.214085  0.185078
# dwpc  0.036127  1.000000  0.463439 -0.037120 -0.027733 -0.071386
# relh -0.849413  0.463439  1.000000 -0.249352 -0.198157 -0.221084
# drct  0.287002 -0.037120 -0.249352  1.000000  0.341961  0.081396
# sknt  0.214085 -0.027733 -0.198157  0.341961  1.000000  0.032931
# vsby  0.185078 -0.071386 -0.221084  0.081396  0.032931  1.000000

# %%
pd.plotting.autocorrelation_plot(vsby);

# %%
pd.plotting.autocorrelation_plot(tmpc);

# %%
pd.plotting.autocorrelation_plot(relh);
