# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,4 # define as dimensões do gráficos a seguir

# %%
# Dados de METAR de Guarulhos nos ano de 2019
df = pd.read_csv('metar_sbgr_maio_2019.csv')

# %%
df=df.drop(['station'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valid   773 non-null    object
#  1   tmpc    773 non-null    float64
#  2   dwpc    773 non-null    float64
#  3   relh    773 non-null    float64
#  4   drct    773 non-null    float64
#  5   sknt    773 non-null    float64
#  6   vsby    773 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 42.4+ KB

# %%
df['datetime'] = pd.to_datetime(df['valid'])
df = df.set_index('datetime')
df.drop(['valid'], axis=1, inplace=True)
df.head()
# Out:
#                      tmpc  dwpc    relh   drct  sknt  vsby
# datetime
# 2019-05-01 00:00:00  20.0  18.0   88.26  130.0   2.0  5.59
# 2019-05-01 01:00:00  20.0  18.0   88.26  150.0   3.0  6.21
# 2019-05-01 02:00:00  20.0  18.0   88.26  130.0   3.0  6.21
# 2019-05-01 03:00:00  18.0  18.0  100.00    0.0   0.0  3.73
# 2019-05-01 04:00:00  18.0  18.0  100.00   90.0   2.0  3.73

# %%
df['2019-05-10':'2019-05-12'].vsby.plot()

# %%
df['2019-05-10':'2019-05-12'].tmpc.plot()

# %%
df['2019-05-10':'2019-05-12'].sknt.plot()
